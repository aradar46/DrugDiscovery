# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1]
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client
# chembl_webresource_client is a Python client for accessing ChEMBL data via the RESTful web services interface.
# this library is used to access ChEMBL database and retrieve bioactivity data for our target of interest.
# ChEMBL is a manually curated database of bioactive molecules with drug-like properties.
# It brings together chemical, bioactivity and genomic data to aid the translation of genomic
# information into effective new drugs.

# %% [markdown]
# ## **Search for Target protein**

# %%
# Target search for Carbonic anhydrase VA
# initialize the target search of chembl
target = new_client.target
target_query = target.search('Carbonic anhydrase VA') # list of dictionaries is returned
targets = pd.DataFrame.from_dict(target_query) # convert to dataframe
targets
# Out:
#                                      cross_references  \
# 0   [{'xref_id': 'P35218', 'xref_name': None, 'xre...
# 1                                                  []
# 2                                                  []
# 3   [{'xref_id': 'P23280', 'xref_name': None, 'xre...
# 4                                                  []
# 5   [{'xref_id': 'P00918', 'xref_name': None, 'xre...
# 6   [{'xref_id': 'P00915', 'xref_name': None, 'xre...
# 7   [{'xref_id': 'P07451', 'xref_name': None, 'xre...
# 8   [{'xref_id': 'P27139', 'xref_name': None, 'xre...
# 9   [{'xref_id': 'Q9ERQ8', 'xref_name': None, 'xre...
# 10  [{'xref_id': 'Q9D6N1', 'xref_name': None, 'xre...
# 11  [{'xref_id': 'Q9Y2D0', 'xref_name': None, 'xre...
# 12  [{'xref_id': 'Q95323', 'xref_name': None, 'xre...
# 13  [{'xref_id': 'P43166', 'xref_name': None, 'xre...
# 14  [{'xref_id': 'Q9ULX7', 'xref_name': None, 'xre...
# 15  [{'xref_id': 'P00920', 'xref_name': None, 'xre...
# 16  [{'xref_id': 'P00921', 'xref_name': None, 'xre...
# 17  [{'xref_id': 'P22748', 'xref_name': None, 'xre...
# 18  [{'xref_id': 'Q8N1Q1', 'xref_name': None, 'xre...
# 19  [{'xref_id': 'Q50565', 'xref_name': None, 'xre...
# 20  [{'xref_id': 'Q99N23', 'xref_name': None, 'xre...
# 21                                                 []
# 22                                                 []
# 23                                                 []
# 24  [{'xref_id': 'P40881', 'xref_name': None, 'xre...
# 25  [{'xref_id': 'P96878', 'xref_name': None, 'xre...
# 26                                                 []
# 27                                                 []
# 28  [{'xref_id': 'Q2PCB5', 'xref_name': None, 'xre...
# 29                                                 []
# 30                                                 []
# 31                                                 []
# 32                                                 []
# 33  [{'xref_id': 'O43570', 'xref_name': None, 'xre...
# 34                                                 []
# 35                                                 []
# 36                                                 []
# 37                                                 []
# 38                                                 []
# 39  [{'xref_id': 'O75493', 'xref_name': None, 'xre...
# 40  [{'xref_id': 'O24855', 'xref_name': None, 'xre...
# 41  [{'xref_id': 'Q6FTL6', 'xref_name': None, 'xre...
# 42  [{'xref_id': 'Q3I4V7', 'xref_name': None, 'xre...
# 43                                                 []
# 44  [{'xref_id': 'Q5AJ71', 'xref_name': None, 'xre...
# 45  [{'xref_id': 'P53615', 'xref_name': None, 'xre...
# 46                                                 []
# 47  [{'xref_id': 'Q16790', 'xref_name': None, 'xre...
# 48                                                 []
# 49  [{'xref_id': 'P64797', 'xref_name': None, 'xre...
# 50                                                 []
# 51                                                 []
# 52                                                 []
# 53                                                 []
# 54                                                 []
# 55                                                 []
# 56                                                 []
# 57                                                 []
#
#                                              organism  \
# 0                                        Homo sapiens
# 1                                        Homo sapiens
# 2                                        Homo sapiens
# 3                                        Homo sapiens
# 4                                          Bos taurus
# 5                                        Homo sapiens
# 6                                        Homo sapiens
# 7                                        Homo sapiens
# 8                                   Rattus norvegicus
# 9                                        Mus musculus
# 10                                       Mus musculus
# 11                                       Homo sapiens
# 12                                         Bos taurus
# 13                                       Homo sapiens
# 14                                       Homo sapiens
# 15                                       Mus musculus
# 16                                         Bos taurus
# 17                                       Homo sapiens
# 18                                       Homo sapiens
# 19               Methanobacterium thermoautotrophicum
# 20                                       Mus musculus
# 21                                         Bos taurus
# 22                                     Macaca mulatta
# 23                                     Equus caballus
# 24                         Methanosarcina thermophila
# 25                         Mycobacterium tuberculosis
# 26                              Stylophora pistillata
# 27                              Stylophora pistillata
# 28                               Dicentrarchus labrax
# 29                              Astrosclera willeyana
# 30                                       Homo sapiens
# 31                          Thalassiosira weissflogii
# 32          Sulfurihydrogenibium sp. (strain YO3AOP1)
# 33                                       Homo sapiens
# 34                                  Flaveria bidentis
# 35                             Brucella suis biovar 1
# 36  Pseudomonas aeruginosa (strain ATCC 15692 / PA...
# 37            Thiomicrospira crunogena (strain XCL-2)
# 38               Trypanosoma cruzi (strain CL Brener)
# 39                                       Homo sapiens
# 40  Helicobacter pylori (strain ATCC 700392 / 2669...
# 41                           Candida glabrata CBS 138
# 42                Cryptococcus neoformans var. grubii
# 43                                  Anopheles gambiae
# 44  Candida albicans (strain SC5314 / ATCC MYA-287...
# 45                     Saccharomyces cerevisiae S288c
# 46                            Drosophila melanogaster
# 47                                       Homo sapiens
# 48                         Mycobacterium tuberculosis
# 49                         Mycobacterium tuberculosis
# 50                            Drosophila melanogaster
# 51                                      Gallus gallus
# 52                                       Mus musculus
# 53                                       Homo sapiens
# 54                                       Mus musculus
# 55                                  Rattus norvegicus
# 56                                       Homo sapiens
# 57                                       Homo sapiens
#
#                                             pref_name  score  \
# 0                               Carbonic anhydrase VA   47.0
# 1                                Carbonic anhydrase V   47.0
# 2                                  Carbonic anhydrase   38.0
# 3                               Carbonic anhydrase VI   30.0
# 4                                  Carbonic anhydrase   30.0
# 5                               Carbonic anhydrase II   28.0
# 6                                Carbonic anhydrase I   28.0
# 7                              Carbonic anhydrase III   27.0
# 8                               Carbonic anhydrase II   27.0
# 9                              Carbonic anhydrase VII   27.0
# 10                            Carbonic anhydrase XIII   27.0
# 11                              Carbonic anhydrase VB   27.0
# 12                              Carbonic anhydrase IV   27.0
# 13                             Carbonic anhydrase VII   27.0
# 14                             Carbonic anhydrase XIV   27.0
# 15                              Carbonic anhydrase II   27.0
# 16                              Carbonic anhydrase II   27.0
# 17                              Carbonic anhydrase IV   27.0
# 18                            Carbonic anhydrase XIII   27.0
# 19                                 Carbonic anhydrase   27.0
# 20                              Carbonic anhydrase 15   27.0
# 21                               Carbonic anhydrase 3   27.0
# 22                               Carbonic anhydrase 1   27.0
# 23                               Carbonic anhydrase 1   27.0
# 24                                 Carbonic anhydrase   26.0
# 25  PROBABLE TRANSMEMBRANE CARBONIC ANHYDRASE (CAR...   26.0
# 26                           Alpha carbonic anhydrase   26.0
# 27                                 Carbonic anhydrase   26.0
# 28                                 Carbonic anhydrase   26.0
# 29                                     Astrosclerin-3   26.0
# 30                       Carbonic anhydrases; II & IX   26.0
# 31                           Delta carbonic anhydrase   26.0
# 32                              Carbonate dehydratase   26.0
# 33                             Carbonic anhydrase XII   25.0
# 34                                 Carbonic anhydrase   25.0
# 35                                 Carbonic anhydrase   25.0
# 36                                 Carbonic anhydrase   25.0
# 37                   Carbonic anhydrase, alpha family   25.0
# 38          Carbonic anhydrase-like protein, putative   25.0
# 39               Carbonic anhydrase-related protein 2   24.0
# 40                               Carbonic anhydrase 1   24.0
# 41                                 Carbonic anhydrase   24.0
# 42                               Carbonic anhydrase 2   24.0
# 43                                      AGAP002992-PA   24.0
# 44                                 Carbonic anhydrase   23.0
# 45                                 Carbonic anhydrase   23.0
# 46                               Carbonic anhydrase 1   23.0
# 47                              Carbonic anhydrase IX   22.0
# 48                                 Carbonic anhydrase   22.0
# 49              Uncharacterized protein Rv1284/MT1322   20.0
# 50                    Carbonic anhydrase 2, isoform A   20.0
# 51                                          Myosin-Va   16.0
# 52                           Unconventional myosin-Va   16.0
# 53                                           VA-ES-BJ   13.0
# 54                                       Vas deferens    7.0
# 55                                       Vas deferens    7.0
# 56           CCR4-NOT transcription complex subunit 6    5.0
# 57      CCR4-NOT transcription complex subunit 6-like    5.0
#
#     species_group_flag target_chembl_id  \
# 0                False       CHEMBL4789
# 1                False    CHEMBL2111457
# 2                False    CHEMBL2095180
# 3                False       CHEMBL3025
# 4                False    CHEMBL2096971
# 5                False        CHEMBL205
# 6                False        CHEMBL261
# 7                False       CHEMBL2885
# 8                False       CHEMBL4706
# 9                False       CHEMBL2216
# 10               False       CHEMBL2186
# 11               False       CHEMBL3969
# 12               False        CHEMBL281
# 13               False       CHEMBL2326
# 14               False       CHEMBL3510
# 15               False       CHEMBL3689
# 16               False       CHEMBL2283
# 17               False       CHEMBL3729
# 18               False       CHEMBL3912
# 19               False       CHEMBL3926
# 20               False       CHEMBL5973
# 21               False    CHEMBL1944498
# 22               False    CHEMBL4105729
# 23               False    CHEMBL4105955
# 24               False       CHEMBL3932
# 25               False       CHEMBL5767
# 26               False    CHEMBL1075028
# 27               False    CHEMBL1649055
# 28               False    CHEMBL1795125
# 29               False    CHEMBL1944499
# 30               False    CHEMBL2096906
# 31               False    CHEMBL3097982
# 32               False    CHEMBL3745586
# 33               False       CHEMBL3242
# 34               False    CHEMBL2401609
# 35               False    CHEMBL3308990
# 36               False    CHEMBL3596083
# 37               False    CHEMBL3621035
# 38               False    CHEMBL4295601
# 39               False       CHEMBL2420
# 40               False       CHEMBL4211
# 41               False       CHEMBL6185
# 42               False    CHEMBL1697676
# 43               False    CHEMBL3399914
# 44               False       CHEMBL5337
# 45               False       CHEMBL5931
# 46               False    CHEMBL2331046
# 47               False       CHEMBL3594
# 48               False       CHEMBL6068
# 49               False       CHEMBL5631
# 50               False    CHEMBL2331045
# 51               False    CHEMBL1781866
# 52               False    CHEMBL4295928
# 53               False    CHEMBL2366259
# 54               False     CHEMBL613599
# 55               False    CHEMBL4651294
# 56               False    CHEMBL3616363
# 57               False    CHEMBL4105957
#
#                                     target_components        target_type  \
# 0   [{'accession': 'P35218', 'component_descriptio...     SINGLE PROTEIN
# 1   [{'accession': 'Q9Y2D0', 'component_descriptio...     PROTEIN FAMILY
# 2   [{'accession': 'P00918', 'component_descriptio...     PROTEIN FAMILY
# 3   [{'accession': 'P23280', 'component_descriptio...     SINGLE PROTEIN
# 4   [{'accession': 'P00921', 'component_descriptio...     PROTEIN FAMILY
# 5   [{'accession': 'P00918', 'component_descriptio...     SINGLE PROTEIN
# 6   [{'accession': 'P00915', 'component_descriptio...     SINGLE PROTEIN
# 7   [{'accession': 'P07451', 'component_descriptio...     SINGLE PROTEIN
# 8   [{'accession': 'P27139', 'component_descriptio...     SINGLE PROTEIN
# 9   [{'accession': 'Q9ERQ8', 'component_descriptio...     SINGLE PROTEIN
# 10  [{'accession': 'Q9D6N1', 'component_descriptio...     SINGLE PROTEIN
# 11  [{'accession': 'Q9Y2D0', 'component_descriptio...     SINGLE PROTEIN
# 12  [{'accession': 'Q95323', 'component_descriptio...     SINGLE PROTEIN
# 13  [{'accession': 'P43166', 'component_descriptio...     SINGLE PROTEIN
# 14  [{'accession': 'Q9ULX7', 'component_descriptio...     SINGLE PROTEIN
# 15  [{'accession': 'P00920', 'component_descriptio...     SINGLE PROTEIN
# 16  [{'accession': 'P00921', 'component_descriptio...     SINGLE PROTEIN
# 17  [{'accession': 'P22748', 'component_descriptio...     SINGLE PROTEIN
# 18  [{'accession': 'Q8N1Q1', 'component_descriptio...     SINGLE PROTEIN
# 19  [{'accession': 'Q50565', 'component_descriptio...     SINGLE PROTEIN
# 20  [{'accession': 'Q99N23', 'component_descriptio...     SINGLE PROTEIN
# 21  [{'accession': 'Q3SZX4', 'component_descriptio...     SINGLE PROTEIN
# 22  [{'accession': 'P00916', 'component_descriptio...     SINGLE PROTEIN
# 23  [{'accession': 'P00917', 'component_descriptio...     SINGLE PROTEIN
# 24  [{'accession': 'P40881', 'component_descriptio...     SINGLE PROTEIN
# 25  [{'accession': 'P96878', 'component_descriptio...     SINGLE PROTEIN
# 26  [{'accession': 'B5SU02', 'component_descriptio...     SINGLE PROTEIN
# 27  [{'accession': 'C0IX24', 'component_descriptio...     SINGLE PROTEIN
# 28  [{'accession': 'Q2PCB5', 'component_descriptio...     SINGLE PROTEIN
# 29  [{'accession': 'A6YCJ1', 'component_descriptio...     SINGLE PROTEIN
# 30  [{'accession': 'P00918', 'component_descriptio...  SELECTIVITY GROUP
# 31  [{'accession': 'Q5U9J1', 'component_descriptio...     SINGLE PROTEIN
# 32  [{'accession': 'B2V8E3', 'component_descriptio...     SINGLE PROTEIN
# 33  [{'accession': 'O43570', 'component_descriptio...     SINGLE PROTEIN
# 34  [{'accession': 'P46510', 'component_descriptio...     SINGLE PROTEIN
# 35  [{'accession': 'A0A0H3GB68', 'component_descri...     SINGLE PROTEIN
# 36  [{'accession': 'Q9HVB9', 'component_descriptio...     SINGLE PROTEIN
# 37  [{'accession': 'Q31FD6', 'component_descriptio...     SINGLE PROTEIN
# 38  [{'accession': 'Q4CVY4', 'component_descriptio...     SINGLE PROTEIN
# 39  [{'accession': 'O75493', 'component_descriptio...     SINGLE PROTEIN
# 40  [{'accession': 'O24855', 'component_descriptio...     SINGLE PROTEIN
# 41  [{'accession': 'Q6FTL6', 'component_descriptio...     SINGLE PROTEIN
# 42  [{'accession': 'Q3I4V7', 'component_descriptio...     SINGLE PROTEIN
# 43  [{'accession': 'Q5TU56', 'component_descriptio...     SINGLE PROTEIN
# 44  [{'accession': 'Q5AJ71', 'component_descriptio...     SINGLE PROTEIN
# 45  [{'accession': 'P53615', 'component_descriptio...     SINGLE PROTEIN
# 46  [{'accession': 'Q9V396', 'component_descriptio...     SINGLE PROTEIN
# 47  [{'accession': 'Q16790', 'component_descriptio...     SINGLE PROTEIN
# 48  [{'accession': 'P9WPJ9', 'component_descriptio...     SINGLE PROTEIN
# 49  [{'accession': 'P9WPJ7', 'component_descriptio...     SINGLE PROTEIN
# 50  [{'accession': 'Q9VTU8', 'component_descriptio...     SINGLE PROTEIN
# 51  [{'accession': 'Q02440', 'component_descriptio...     SINGLE PROTEIN
# 52  [{'accession': 'Q99104', 'component_descriptio...     SINGLE PROTEIN
# 53                                                 []          CELL-LINE
# 54                                                 []             TISSUE
# 55                                                 []             TISSUE
# 56  [{'accession': 'Q9ULM6', 'component_descriptio...     SINGLE PROTEIN
# 57  [{'accession': 'Q96LI5', 'component_descriptio...     SINGLE PROTEIN
#
#     tax_id
# 0     9606
# 1     9606
# 2     9606
# 3     9606
# 4     9913
# 5     9606
# 6     9606
# 7     9606
# 8    10116
# 9    10090
# 10   10090
# 11    9606
# 12    9913
# 13    9606
# 14    9606
# 15   10090
# 16    9913
# 17    9606
# 18    9606
# 19  187420
# 20   10090
# 21    9913
# 22    9544
# 23    9796
# 24    2210
# 25    1773
# 26   50429
# 27   50429
# 28   13489
# 29   85810
# 30    9606
# 31   67004
# 32  436114
# 33    9606
# 34    4224
# 35  204722
# 36  208964
# 37  317025
# 38  353153
# 39    9606
# 40   85962
# 41  284593
# 42  178876
# 43    7165
# 44  237561
# 45  559292
# 46    7227
# 47    9606
# 48    1773
# 49    1773
# 50    7227
# 51    9031
# 52   10090
# 53    9606
# 54   10090
# 55   10116
# 56    9606
# 57    9606

# %%
# Select and retrieve bioactivity data for the target of interest 
selected_target = targets.target_chembl_id[6]
print(selected_target)
# initialize the bioactivity data
activity = new_client.activity
# retrieve the bioactivity data for the selected target of interest with IC50 as standard type
# IC50 is the concentration of a drug required to inhibit the growth of a microorganism by 50%.
# The IC50 is a measure of the potency of a drug.
# The lower the IC50 value, the more potent the drug.
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")
df = pd.DataFrame.from_dict(res)
df.shape
# Out:
# CHEMBL261
# (350, 45)

# %%
# df head show all the columns
df.head(3)
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None       651622                  []    CHEMBL662716
# 1             None       651633                  []    CHEMBL662716
# 2             None       651637                  []    CHEMBL662716
#
#                                    assay_description assay_type  \
# 0  Inhibitory activity against human carbonic anh...          B
# 1  Inhibitory activity against human carbonic anh...          B
# 2  Inhibitory activity against human carbonic anh...          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000190  BAO_0000357
# 1                    None                   None  BAO_0000190  BAO_0000357
# 2                    None                   None  BAO_0000190  BAO_0000357
#
#    ... target_organism      target_pref_name target_tax_id text_value  toid  \
# 0  ...    Homo sapiens  Carbonic anhydrase I          9606       None  None
# 1  ...    Homo sapiens  Carbonic anhydrase I          9606       None  None
# 2  ...    Homo sapiens  Carbonic anhydrase I          9606       None  None
#
#    type  units    uo_units upper_value    value
# 0  IC50     nM  UO_0000065        None    250.0
# 1  IC50     nM  UO_0000065        None     50.0
# 2  IC50     nM  UO_0000065        None  50000.0
#
# [3 rows x 45 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('Data/01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
# Remove columns with missing values in the standard_value column
df2 = df[df.standard_value.notna()]
# Remove columns with missing values in the canonical_smiles column
# canonical_smiles is a unique representation of a molecule in the form of a string.
# example: Cc1ccccc1C(=O)Nc1ccc(O)cc1
# we will use this column to calculate molecular descriptors?
# molecular descriptors are numerical values that describe the chemical properties of a molecule.
df2 = df2[df.canonical_smiles.notna()]
df2.head(3)
# Out:
# /tmp/ipykernel_24231/3785007853.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None       651622                  []    CHEMBL662716
# 1             None       651633                  []    CHEMBL662716
# 2             None       651637                  []    CHEMBL662716
#
#                                    assay_description assay_type  \
# 0  Inhibitory activity against human carbonic anh...          B
# 1  Inhibitory activity against human carbonic anh...          B
# 2  Inhibitory activity against human carbonic anh...          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000190  BAO_0000357
# 1                    None                   None  BAO_0000190  BAO_0000357
# 2                    None                   None  BAO_0000190  BAO_0000357
#
#    ... target_organism      target_pref_name target_tax_id text_value  toid  \
# 0  ...    Homo sapiens  Carbonic anhydrase I          9606       None  None
# 1  ...    Homo sapiens  Carbonic anhydrase I          9606       None  None
# 2  ...    Homo sapiens  Carbonic anhydrase I          9606       None  None
#
#    type  units    uo_units upper_value    value
# 0  IC50     nM  UO_0000065        None    250.0
# 1  IC50     nM  UO_0000065        None     50.0
# 2  IC50     nM  UO_0000065        None  50000.0
#
# [3 rows x 45 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 282

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr.shape
# Out:
# (282, 45)

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0             CHEMBL20                         CC(=O)Nc1nnc(S(N)(=O)=O)s1
# 1             CHEMBL19                     CC(=O)/N=c1/sc(S(N)(=O)=O)nn1C
# 2            CHEMBL118  Cc1ccc(-c2cc(C(F)(F)F)nn2-c2ccc(S(N)(=O)=O)cc2...
# 3          CHEMBL26915        COc1ccc(-n2nc(C(F)(F)F)cc2-c2ccc(Cl)cc2)cc1
# 4            CHEMBL139                     O=C(O)Cc1ccccc1Nc1c(Cl)cccc1Cl
# ..                 ...                                                ...
# 345      CHEMBL4863113  COC(=O)[C@H]1O[C@@H](NC(=O)c2ccc(S(N)(=O)=O)cc...
# 346      CHEMBL4865818  NS(=O)(=O)c1ccc(C(=O)N[C@@H]2O[C@H](CO)[C@@H](...
# 347      CHEMBL4870385  NS(=O)(=O)OC[C@H]1C[C@@H](Nc2ncncc2C(=O)c2ccn(...
# 348      CHEMBL4856793  Cc1sc(C(=O)c2cncnc2N[C@H]2C[C@H](O)[C@@H](COS(...
# 349      CHEMBL4862901  Cc1sc(C(=O)c2cncnc2N[C@H]2C[C@H](O)[C@@H](COS(...
#
#     standard_value
# 0            250.0
# 1             50.0
# 2          50000.0
# 3         100000.0
# 4         100000.0
# ..             ...
# 345         1800.0
# 346         3600.0
# 347           50.0
# 348           50.0
# 349           90.0
#
# [282 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('Data/02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('Data/02_bioactivity_data_preprocessed.csv')

# %%
# activity_class is a new column that will be created to classify the bioactivity of the molecules
# based on the standard_value column
def bioactivity_level(value):
  if value >= 10000:
    return "inactive"
  elif value <= 1000:
    return "active"
  else:
    return "intermediate"

df4['class'] = df4['standard_value'].apply(lambda x: bioactivity_level(float(x)))
df4
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0             CHEMBL20                         CC(=O)Nc1nnc(S(N)(=O)=O)s1
# 1             CHEMBL19                     CC(=O)/N=c1/sc(S(N)(=O)=O)nn1C
# 2            CHEMBL118  Cc1ccc(-c2cc(C(F)(F)F)nn2-c2ccc(S(N)(=O)=O)cc2...
# 3          CHEMBL26915        COc1ccc(-n2nc(C(F)(F)F)cc2-c2ccc(Cl)cc2)cc1
# 4            CHEMBL139                     O=C(O)Cc1ccccc1Nc1c(Cl)cccc1Cl
# ..                 ...                                                ...
# 277      CHEMBL4863113  COC(=O)[C@H]1O[C@@H](NC(=O)c2ccc(S(N)(=O)=O)cc...
# 278      CHEMBL4865818  NS(=O)(=O)c1ccc(C(=O)N[C@@H]2O[C@H](CO)[C@@H](...
# 279      CHEMBL4870385  NS(=O)(=O)OC[C@H]1C[C@@H](Nc2ncncc2C(=O)c2ccn(...
# 280      CHEMBL4856793  Cc1sc(C(=O)c2cncnc2N[C@H]2C[C@H](O)[C@@H](COS(...
# 281      CHEMBL4862901  Cc1sc(C(=O)c2cncnc2N[C@H]2C[C@H](O)[C@@H](COS(...
#
#      standard_value         class
# 0             250.0        active
# 1              50.0        active
# 2           50000.0      inactive
# 3          100000.0      inactive
# 4          100000.0      inactive
# ..              ...           ...
# 277          1800.0  intermediate
# 278          3600.0  intermediate
# 279            50.0        active
# 280            50.0        active
# 281            90.0        active
#
# [282 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df4.to_csv('Data/03_bioactivity_data_curated.csv', index=False)

# %%
! rm 'Data/bioactivity.zip'
! zip 'Data/bioactivity.zip' Data/*.csv
# Out:
# rm: cannot remove 'Data/bioactivity.zip': No such file or directory
#   adding: Data/01_bioactivity_data_raw.csv (deflated 90%)
#   adding: Data/02_bioactivity_data_preprocessed.csv (deflated 78%)
#   adding: Data/03_bioactivity_data_curated.csv (deflated 80%)

# %%
! ls -l
# Out:
# total 1044
# -rw-rw-r-- 1 adr adr 101143 feb  7 01:09 CDD_ML_Part_01.ipynb
# -rw-rw-r-- 1 adr adr 295105 feb  7 00:44 CDD_ML_Part_02.ipynb
# -rw-rw-r-- 1 adr adr  95731 feb  7 00:45 CDD_ML_Part_03.ipynb
# -rw-rw-r-- 1 adr adr  52379 feb  7 00:45 CDD_ML_Part_04.ipynb
# -rw-rw-r-- 1 adr adr 511768 feb  7 00:47 CDD_ML_Part_05.ipynb
# drwxrwxr-x 2 adr adr   4096 feb  7 01:09 Data
